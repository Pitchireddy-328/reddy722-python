# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[10,50,10,40,20]

plt.xlabel('Day')
plt.ylabel('Temp')
plt.title('Weather')

plt.plot(x,y,1,color='green',linewidth=5,linestyle='dotted',marker='+',mec='red')

plt.grid()
plt.show()
